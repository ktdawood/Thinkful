# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.path.isfile('/home/kaneeshadawood/flights.csv')
# Out:
# True

# %%
df = pd.read_csv('/home/kaneeshadawood/flights.csv')
df.head(5)
# Out:
#    MEMBER_NO   FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0      54993  11/2/2006        12/24/2008   Male         6            .
# 1      28065  2/19/2007          8/3/2007   Male         6          NaN
# 2      55106   2/1/2007         8/30/2007   Male         6            .
# 3      21189  8/22/2008         8/23/2008   Male         5  Los Angeles
# 4      39546  4/10/2009         4/15/2009   Male         6      guiyang
#
#   WORK_PROVINCE WORK_COUNTRY   AGE  LOAD_TIME  ...  SUM_YR_2  SEG_KM_SUM  \
# 0       beijing           CN  31.0  3/31/2014  ...  234188.0      580717
# 1       beijing           CN  42.0  3/31/2014  ...  167434.0      293678
# 2       beijing           CN  40.0  3/31/2014  ...  164982.0      283712
# 3            CA           US  64.0  3/31/2014  ...  125500.0      281336
# 4       guizhou           CN  48.0  3/31/2014  ...  130702.0      309928
#
#    LAST_FLIGHT_DATE  LAST_TO_END  AVG_INTERVAL MAX_INTERVAL  EXCHANGE_COUNT  \
# ...

# %%
df.dtypes
# Out:
# MEMBER_NO              int64
# FFP_DATE              object
# FIRST_FLIGHT_DATE     object
# GENDER                object
# FFP_TIER               int64
# WORK_CITY             object
# WORK_PROVINCE         object
# WORK_COUNTRY          object
# AGE                  float64
# LOAD_TIME             object
# FLIGHT_COUNT           int64
# BP_SUM                 int64
# SUM_YR_1             float64
# SUM_YR_2             float64
# SEG_KM_SUM             int64
# LAST_FLIGHT_DATE      object
# LAST_TO_END            int64
# AVG_INTERVAL         float64
# MAX_INTERVAL           int64
# EXCHANGE_COUNT         int64
# avg_discount         float64
# Points_Sum             int64
# Point_NotFlight        int64
# dtype: object

# %%
df["MEMBER_NO"].count()
# Out:
# 62988

# %% [markdown]
# # PART ONE

# %% [markdown]
# Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#     + Choose one variable and plot that variable four different ways.
#     + Choose two continuous variables, and plot them three different ways.
#     + Choose one continuous variable and one categorical variable, and plot them six different ways.
#     + Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.

# %% [markdown]
# # Continuous Variable:

# %%
# Plot 1

sns.distplot(df['FLIGHT_COUNT'], color = 'b')

# %%
# Plot 2

sns.set(style = 'darkgrid')
g = sns.factorplot(y="FLIGHT_COUNT", data=df,
                   size=6, kind="violin", palette="pastel")
plt.show()
# Out:
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/seaborn/categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Plot 3
sns.boxplot(x = df['FLIGHT_COUNT'])

# %%
# Plot 4
sns.pointplot(x= 'FLIGHT_COUNT', data = df, orient = 'v')

# %% [markdown]
# # Two Continuous Variables

# %%
# Plot 1
sns.lmplot("FLIGHT_COUNT", "AVG_INTERVAL", data = df, fit_reg = False, palette = 'pastel', size = 5)
# Out:
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/seaborn/regression.py:546: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Plot 2
sns.jointplot(x="FLIGHT_COUNT", y="AVG_INTERVAL", data=df, kind="reg", size = 8)
# Out:
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Plot 3
sns.jointplot(x="FLIGHT_COUNT", y="AVG_INTERVAL", data=df, kind="hex", size = 8, color='r')

# %% [markdown]
# # Continuous Variable and Categorical Variable

# %%
# Plot 1

sns.set(style = 'darkgrid')
g = sns.factorplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500],
                   size=6, kind="bar", palette="pastel",ci=95)
plt.show()

# %%
# Plot2

sns.stripplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500], jitter=True, palette = 'pastel')

# %%
#Plot 3

sns.boxplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500], palette = 'pastel')

# %%
# Plot 4
sns.pointplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500], palette = 'pastel', ci = 99.99)

# %%
# Plot 5
sns.set(style = 'darkgrid')
g = sns.factorplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500],
                   size=6, kind="violin", palette="pastel")
plt.show()

# %%
# Plot 6:
sns.set(style = 'darkgrid')
g = sns.factorplot(x="GENDER", y="AGE", data=df[lambda df: df['AGE'] < 500],
                   size=6, kind="boxen", palette="pastel")
plt.show()

# %% [markdown]
# # Illustration on Plots:
#
# 1. distplot: Plots a univariate distribution of observations and an approximate density of the dataset
#
# 2. boxplot: Shows the distribution of quantitative data which facilitates comparisons between variables.
#
# 3. lmplot: Seaborn lmplot is a 2D scatter plot with a regression line.
#
# 4. jointplot: Plots two variables with bivariate and univariate graphs.
#
# 5. stripplot: Shows all observations and a representation of some distribution
#
# 6. violinplot: A violin plot displays both density and probability distribution of a numerical variable.
#     Pros:
#     Shows summary statistics of a given variable.
#     Unlike a box plot, shows the full distribution of the data. This allows for easy spotting of multimodal data.
#     Cons:
#     Violin plots are less known to wide audience meaning it may be harder to grasp.
#
# 7. factorplot:
#
# 8. pointplot:
#
# 9. boxenplot:

# %% [markdown]
# # PART TWO

# %% [markdown]
# Find a dataset with at least four continuous variables and one categorical variable. Create one master plot that gives insight into the variables and their interrelationships, including:
#     + Probability distributions
#     + Bivariate relationships
#     + Whether the distributions or the relationships vary across groups
#     + Accompany your plot with a written description of what you see.

# %%
import os
os.path.isfile('/home/kaneeshadawood/gapminder.csv')
# Out:
# True

# %%
df = pd.read_csv('/home/kaneeshadawood/gapminder.csv') 
df.head()
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#     gdp-1      region
# 0  1182.0  South Asia
# 1  1168.0  South Asia
# 2  1173.0  South Asia
# 3  1187.0  South Asia
# 4  1178.0  South Asia

# %%
df.describe()
# Out:
#                Year     fertility          life    population  \
# count  10111.000000  10100.000000  10111.000000  1.010800e+04
# mean    1988.514588      4.028719     64.078600  2.560448e+07
# std       14.430849      2.013968     11.122779  1.032383e+08
# min     1964.000000      0.836000      6.000000  1.170000e+03
# 25%     1976.000000      2.175750     56.282500  8.874062e+05
# 50%     1989.000000      3.632500     67.157000  4.765781e+06
# 75%     2001.000000      5.905250     72.484000  1.476995e+07
# max     2013.000000      9.223000     83.580000  1.359368e+09
#
#        child_mortality            gdp          gdp-1
# count      9210.000000    9000.000000    8999.000000
# mean         80.834505   12746.916667   12748.201800
# std          79.220942   17797.809953   17798.381302
# min           2.000000     142.000000     142.000000
# 25%          18.900000    2263.000000    2264.500000
# 50%          50.700000    6438.500000    6440.000000
# ...

# %%
# Default pairplot
sns.pairplot(df)
# Out:
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/kaneeshadawood/.local/lib/python3.5/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
